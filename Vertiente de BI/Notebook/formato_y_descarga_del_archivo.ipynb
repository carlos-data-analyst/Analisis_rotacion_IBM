# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/drive/MyDrive/Diplomado ITPE/Proyecto/Proyecto Modulo 2 - Regresión Logistica - Rotación de IBM/WA_Fn-UseC_-HR-Employee-Attrition (1).csv")

# %%
df.head().T
# Out:
#                                         0                       1  \
# Age                                    41                      49
# Attrition                             Yes                      No
# BusinessTravel              Travel_Rarely       Travel_Frequently
# DailyRate                            1102                     279
# Department                          Sales  Research & Development
# DistanceFromHome                        1                       8
# Education                               2                       1
# EducationField              Life Sciences           Life Sciences
# EmployeeCount                           1                       1
# EmployeeNumber                          1                       2
# EnvironmentSatisfaction                 2                       3
# Gender                             Female                    Male
# HourlyRate                             94                      61
# ...

# %%
# 1. Convertir el DataFrame de pandas a un archivo .xlsx local en Colab
df.to_excel('analisis_ibm_attrition.xlsx', index=False)

# %%
# 2. Descargar el archivo generado directamente a tu computadora
from google.colab import files
files.download('analisis_ibm_attrition.xlsx')
